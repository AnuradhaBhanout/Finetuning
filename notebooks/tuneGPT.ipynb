# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install -q transformers peft trl datasets accelerate

# %%
# !ls /content/drive/MyDrive/Finetuning/
# Out:
# data  train.py

# %%
# !pip install -q -U torchao

# %%
# !pip uninstall -y torchao
# Out:
# Found existing installation: torchao 0.17.0
# Uninstalling torchao-0.17.0:
#   Successfully uninstalled torchao-0.17.0

# %%
# !python /content/drive/MyDrive/Finetuning/train.py \
    --train_file /content/drive/MyDrive/Finetuning/data/train.jsonl \
    --val_file /content/drive/MyDrive/Finetuning/data/val.jsonl \
    --output_dir /content/drive/MyDrive/Finetuning/checkpoints/gpt2-skyrim-lora
# Out:
# Loading tokenizer/model: gpt2
# ...
# Loading weights: 100% 148/148 [00:00<00:00, 5740.52it/s]
# /usr/local/lib/python3.12/dist-packages/peft/tuners/lora/layer.py:2504: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# trainable params: 294,912 || all params: 124,734,720 || trainable%: 0.2364
# Loading dataset...
# Generating train split: 3923 examples [00:00, 282239.05 examples/s]
# Generating validation split: 217 examples [00:00, 46000.40 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'speaker', 'context'],
#         num_rows: 3923
#     })
#     validation: Dataset({
#         features: ['text', 'speaker', 'context'],
#         num_rows: 217
#     })
# })
# Adding EOS to train dataset: 100% 3923/3923 [00:00<00:00, 15747.45 examples/s]
# Tokenizing train dataset: 100% 3923/3923 [00:01<00:00, 2422.14 examples/s]
# ...

# %%
# !python /content/drive/MyDrive/Finetuning/generate.py \
    --adapter_dir /content/drive/MyDrive/Finetuning/checkpoints/gpt2-skyrim-lora/final \
    --base_model gpt2
# Out:
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Loading base model: gpt2
# ...
# Loading weights: 100% 148/148 [00:00<00:00, 6095.29it/s]
# Loading LoRA adapter from: /content/drive/MyDrive/Finetuning/checkpoints/gpt2-skyrim-lora/final
#
# Generating on device: cuda
#
# ...
#
# [Belethor] — Greeting a customer entering his shop
# ----------------------------------------------------------------------
#   (1) Sure. I thought I was going to give you a good deal on something.
#   (2) I'll be right back.
#
# [Nazeem] — Boasting about the Cloud District
# ----------------------------------------------------------------------
# ...

# %%
# !python /content/drive/MyDrive/Finetuning/generate_base.py --base_model gpt2
# Out:
# Loading BASE model (no adapter): gpt2
# ...
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 159kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 10.6MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 22.0MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 7.64MB/s]
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Loading weights: 100% 148/148 [00:00<00:00, 7394.63it/s]
#
# Generating on device: cuda
#
# ...
#
# [Belethor] — Greeting a customer entering his shop
# ----------------------------------------------------------------------
# ...
